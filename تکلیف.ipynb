# %%
import numpy as np
import matplotlib.pyplot as mp

# %% [markdown]
# نمودار خطی درس خواندن من

# %%
x = np.array([1,2,3,4,5,6])
y = np.array([15,25,20,30,40,50])
mp.plot(x,y)
mp.xlabel('day')
mp.ylabel('hour')
mp.scatter(x,y)
mp.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
